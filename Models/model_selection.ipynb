# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df1 = pd.read_pickle('electronic_df_EDAv1.pkl')
df2 = pd.read_pickle('electronic_df_EDAv2.pkl')
df3 = pd.read_pickle('electronic_df_EDAv3.pkl')

# %%
electronic_df = pd.read_pickle('cleaned_electronic_df_new.pkl')

# %%
electronic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36829 entries, 0 to 36828
# Columns: 2304 entries, tonal.tuning_nontempered_energy_ratio to mbdata.dnb
# dtypes: bool(4), float64(2294), object(6)
# memory usage: 646.4+ MB

# %%
df1.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36829 entries, 0 to 36828
# Data columns (total 613 columns):
#  #    Column                                          Non-Null Count  Dtype
# ---   ------                                          --------------  -----
#  0    lowlevel.average_loudness                       36829 non-null  float64
#  1    lowlevel.barkbands_crest.dvar                   36829 non-null  float64
#  2    lowlevel.barkbands_crest.max                    36829 non-null  float64
#  3    lowlevel.barkbands_crest.min                    36829 non-null  float64
#  4    lowlevel.barkbands_crest.var                    36829 non-null  float64
#  5    lowlevel.barkbands_flatness_db.min              36829 non-null  float64
#  6    lowlevel.barkbands_kurtosis.max                 36829 non-null  float64
#  7    lowlevel.barkbands_kurtosis.mean                36829 non-null  float64
#  8    lowlevel.barkbands_kurtosis.median              36829 non-null  float64
#  9    lowlevel.barkbands_kurtosis.min                 36829 non-null  float64
#  10   lowlevel.barkbands_skewness.dvar                36829 non-null  float64
#  11   lowlevel.barkbands_skewness.max                 36829 non-null  float64
#  12   lowlevel.barkbands_skewness.mean                36829 non-null  float64
#  13   lowlevel.barkbands_skewness.min                 36829 non-null  float64
#  14   lowlevel.barkbands_skewness.var                 36829 non-null  float64
#  15   lowlevel.barkbands_spread.dvar                  36829 non-null  float64
#  16   lowlevel.barkbands_spread.max                   36829 non-null  float64
#  17   lowlevel.barkbands_spread.min                   36829 non-null  float64
#  18   lowlevel.barkbands_spread.var                   36829 non-null  float64
#  19   lowlevel.dissonance.max                         36829 non-null  float64
#  20   lowlevel.dissonance.min                         36829 non-null  float64
#  21   lowlevel.dynamic_complexity                     36829 non-null  float64
#  22   lowlevel.erbbands_crest.dmean                   36829 non-null  float64
#  23   lowlevel.erbbands_crest.max                     36829 non-null  float64
#  24   lowlevel.erbbands_crest.mean                    36829 non-null  float64
#  25   lowlevel.erbbands_crest.min                     36829 non-null  float64
#  26   lowlevel.erbbands_crest.var                     36829 non-null  float64
#  27   lowlevel.erbbands_flatness_db.max               36829 non-null  float64
#  28   lowlevel.erbbands_flatness_db.min               36829 non-null  float64
#  29   lowlevel.erbbands_flatness_db.var               36829 non-null  float64
#  30   lowlevel.erbbands_kurtosis.mean                 36829 non-null  float64
#  31   lowlevel.erbbands_kurtosis.median               36829 non-null  float64
#  32   lowlevel.erbbands_kurtosis.min                  36829 non-null  float64
#  33   lowlevel.erbbands_skewness.dmean                36829 non-null  float64
#  34   lowlevel.erbbands_skewness.mean                 36829 non-null  float64
#  35   lowlevel.erbbands_skewness.min                  36829 non-null  float64
#  36   lowlevel.erbbands_skewness.var                  36829 non-null  float64
#  37   lowlevel.erbbands_spread.dmean                  36829 non-null  float64
#  38   lowlevel.erbbands_spread.max                    36829 non-null  float64
#  39   lowlevel.erbbands_spread.mean                   36829 non-null  float64
#  40   lowlevel.erbbands_spread.min                    36829 non-null  float64
#  41   lowlevel.erbbands_spread.var                    36829 non-null  float64
#  42   lowlevel.hfc.min                                36829 non-null  float64
#  43   lowlevel.hfc.var                                36829 non-null  float64
#  44   lowlevel.melbands_crest.dmean                   36829 non-null  float64
#  45   lowlevel.melbands_crest.dvar                    36829 non-null  float64
#  46   lowlevel.melbands_crest.max                     36829 non-null  float64
#  47   lowlevel.melbands_crest.mean                    36829 non-null  float64
#  48   lowlevel.melbands_crest.min                     36829 non-null  float64
#  49   lowlevel.melbands_crest.var                     36829 non-null  float64
#  50   lowlevel.melbands_flatness_db.min               36829 non-null  float64
#  51   lowlevel.melbands_kurtosis.dmean                36829 non-null  float64
#  52   lowlevel.melbands_kurtosis.min                  36829 non-null  float64
#  53   lowlevel.melbands_skewness.dmean                36829 non-null  float64
#  54   lowlevel.melbands_skewness.min                  36829 non-null  float64
#  55   lowlevel.melbands_spread.dmean                  36829 non-null  float64
#  56   lowlevel.melbands_spread.max                    36829 non-null  float64
#  57   lowlevel.melbands_spread.min                    36829 non-null  float64
#  58   lowlevel.melbands_spread.var                    36829 non-null  float64
#  59   lowlevel.pitch_salience.dvar                    36829 non-null  float64
#  60   lowlevel.pitch_salience.max                     36829 non-null  float64
#  61   lowlevel.pitch_salience.min                     36829 non-null  float64
#  62   lowlevel.pitch_salience.var                     36829 non-null  float64
#  63   lowlevel.silence_rate_20dB.mean                 36829 non-null  float64
#  64   lowlevel.silence_rate_20dB.median               36829 non-null  float64
#  65   lowlevel.silence_rate_20dB.min                  36829 non-null  float64
#  66   lowlevel.silence_rate_30dB.dmean                36829 non-null  float64
#  67   lowlevel.silence_rate_30dB.mean                 36829 non-null  float64
#  68   lowlevel.silence_rate_30dB.median               36829 non-null  float64
#  69   lowlevel.silence_rate_30dB.min                  36829 non-null  float64
#  70   lowlevel.silence_rate_60dB.dmean                36829 non-null  float64
#  71   lowlevel.silence_rate_60dB.max                  36829 non-null  float64
#  72   lowlevel.silence_rate_60dB.mean                 36829 non-null  float64
#  73   lowlevel.silence_rate_60dB.median               36829 non-null  float64
#  74   lowlevel.spectral_centroid.dvar                 36829 non-null  float64
#  75   lowlevel.spectral_centroid.min                  36829 non-null  float64
#  76   lowlevel.spectral_centroid.var                  36829 non-null  float64
#  77   lowlevel.spectral_complexity.dmean              36829 non-null  float64
#  78   lowlevel.spectral_complexity.dvar               36829 non-null  float64
#  79   lowlevel.spectral_complexity.max                36829 non-null  float64
#  80   lowlevel.spectral_complexity.mean               36829 non-null  float64
#  81   lowlevel.spectral_complexity.min                36829 non-null  float64
#  82   lowlevel.spectral_complexity.var                36829 non-null  float64
#  83   lowlevel.spectral_energyband_high.dmean         36829 non-null  float64
#  84   lowlevel.spectral_energyband_high.dvar          36829 non-null  float64
#  85   lowlevel.spectral_energyband_high.max           36829 non-null  float64
#  86   lowlevel.spectral_energyband_high.mean          36829 non-null  float64
#  87   lowlevel.spectral_energyband_high.median        36829 non-null  float64
#  88   lowlevel.spectral_energyband_high.min           36829 non-null  float64
#  89   lowlevel.spectral_energyband_high.var           36829 non-null  float64
#  90   lowlevel.spectral_energyband_low.dvar           36829 non-null  float64
#  91   lowlevel.spectral_energyband_low.median         36829 non-null  float64
#  92   lowlevel.spectral_energyband_low.min            36829 non-null  float64
#  93   lowlevel.spectral_energyband_low.var            36829 non-null  float64
#  94   lowlevel.spectral_energyband_middle_high.dmean  36829 non-null  float64
#  95   lowlevel.spectral_energyband_middle_high.dvar   36829 non-null  float64
#  96   lowlevel.spectral_energyband_middle_high.max    36829 non-null  float64
#  97   lowlevel.spectral_energyband_middle_high.mean   36829 non-null  float64
#  98   lowlevel.spectral_energyband_middle_high.min    36829 non-null  float64
#  99   lowlevel.spectral_energyband_middle_high.var    36829 non-null  float64
#  100  lowlevel.spectral_energyband_middle_low.dmean   36829 non-null  float64
#  101  lowlevel.spectral_energyband_middle_low.dvar    36829 non-null  float64
#  102  lowlevel.spectral_energyband_middle_low.max     36829 non-null  float64
#  103  lowlevel.spectral_energyband_middle_low.mean    36829 non-null  float64
#  104  lowlevel.spectral_energyband_middle_low.min     36829 non-null  float64
#  105  lowlevel.spectral_energyband_middle_low.var     36829 non-null  float64
#  106  lowlevel.spectral_entropy.min                   36829 non-null  float64
#  107  lowlevel.spectral_entropy.var                   36829 non-null  float64
#  108  lowlevel.spectral_flux.mean                     36829 non-null  float64
#  109  lowlevel.spectral_flux.min                      36829 non-null  float64
#  110  lowlevel.spectral_flux.var                      36829 non-null  float64
#  111  lowlevel.spectral_kurtosis.min                  36829 non-null  float64
#  112  lowlevel.spectral_rms.var                       36829 non-null  float64
#  113  lowlevel.spectral_rolloff.max                   36829 non-null  float64
#  114  lowlevel.spectral_rolloff.median                36829 non-null  float64
#  115  lowlevel.spectral_rolloff.min                   36829 non-null  float64
#  116  lowlevel.spectral_rolloff.var                   36829 non-null  float64
#  117  lowlevel.spectral_skewness.dmean                36829 non-null  float64
#  118  lowlevel.spectral_skewness.dvar                 36829 non-null  float64
#  119  lowlevel.spectral_skewness.min                  36829 non-null  float64
#  120  lowlevel.spectral_spread.dmean                  36829 non-null  float64
#  121  lowlevel.spectral_spread.dvar                   36829 non-null  float64
#  122  lowlevel.spectral_spread.mean                   36829 non-null  float64
#  123  lowlevel.spectral_spread.min                    36829 non-null  float64
#  124  lowlevel.spectral_spread.var                    36829 non-null  float64
#  125  lowlevel.spectral_strongpeak.max                36829 non-null  float64
#  126  lowlevel.spectral_strongpeak.median             36829 non-null  float64
#  127  lowlevel.spectral_strongpeak.min                36829 non-null  float64
#  128  lowlevel.zerocrossingrate.dvar                  36829 non-null  float64
#  129  lowlevel.zerocrossingrate.max                   36829 non-null  float64
#  130  lowlevel.zerocrossingrate.min                   36829 non-null  float64
#  131  lowlevel.zerocrossingrate.var                   36829 non-null  float64
#  132  rhythm.beats_count                              36829 non-null  float64
#  133  rhythm.beats_loudness.dmean                     36829 non-null  float64
#  134  rhythm.beats_loudness.dvar                      36829 non-null  float64
#  135  rhythm.beats_loudness.mean                      36829 non-null  float64
#  136  rhythm.beats_loudness.min                       36829 non-null  float64
#  137  rhythm.bpm_histogram_first_peak_bpm.min         36829 non-null  float64
#  138  rhythm.bpm_histogram_first_peak_spread.min      36829 non-null  float64
#  139  rhythm.bpm_histogram_first_peak_weight.min      36829 non-null  float64
#  140  rhythm.bpm_histogram_second_peak_bpm.min        36829 non-null  float64
#  141  rhythm.bpm_histogram_second_peak_spread.min     36829 non-null  float64
#  142  rhythm.bpm_histogram_second_peak_weight.min     36829 non-null  float64
#  143  rhythm.danceability                             36829 non-null  float64
#  144  rhythm.onset_rate                               36829 non-null  float64
#  145  tonal.chords_changes_rate                       36829 non-null  float64
#  146  tonal.chords_number_rate                        36829 non-null  float64
#  147  tonal.chords_strength.dmean                     36829 non-null  float64
#  148  tonal.chords_strength.dvar                      36829 non-null  float64
#  149  tonal.chords_strength.max                       36829 non-null  float64
#  150  tonal.chords_strength.mean                      36829 non-null  float64
#  151  tonal.chords_strength.min                       36829 non-null  float64
#  152  tonal.chords_strength.var                       36829 non-null  float64
#  153  tonal.hpcp_entropy.dmean                        36829 non-null  float64
#  154  tonal.hpcp_entropy.max                          36829 non-null  float64
#  155  tonal.hpcp_entropy.mean                         36829 non-null  float64
#  156  tonal.hpcp_entropy.min                          36829 non-null  float64
#  157  tonal.hpcp_entropy.var                          36829 non-null  float64
#  158  tonal.key_strength                              36829 non-null  float64
#  159  tonal.tuning_diatonic_strength                  36829 non-null  float64
#  160  tonal.tuning_equal_tempered_deviation           36829 non-null  float64
#  161  tonal.tuning_frequency                          36829 non-null  float64
#  162  tonal.tuning_nontempered_energy_ratio           36829 non-null  float64
#  163  lowlevel.barkbands.PCA.0                        36829 non-null  float64
#  164  lowlevel.barkbands.PCA.1                        36829 non-null  float64
#  165  lowlevel.barkbands.PCA.2                        36829 non-null  float64
#  166  lowlevel.barkbands.PCA.3                        36829 non-null  float64
#  167  lowlevel.barkbands.PCA.4                        36829 non-null  float64
#  168  lowlevel.barkbands.PCA.5                        36829 non-null  float64
#  169  lowlevel.barkbands.PCA.6                        36829 non-null  float64
#  170  lowlevel.barkbands.PCA.7                        36829 non-null  float64
#  171  lowlevel.barkbands.PCA.8                        36829 non-null  float64
#  172  lowlevel.barkbands.PCA.9                        36829 non-null  float64
#  173  lowlevel.barkbands.PCA.10                       36829 non-null  float64
#  174  lowlevel.barkbands.PCA.11                       36829 non-null  float64
#  175  lowlevel.barkbands.PCA.12                       36829 non-null  float64
#  176  lowlevel.barkbands.PCA.13                       36829 non-null  float64
#  177  lowlevel.barkbands.PCA.14                       36829 non-null  float64
#  178  lowlevel.barkbands.PCA.15                       36829 non-null  float64
#  179  lowlevel.barkbands.PCA.16                       36829 non-null  float64
#  180  lowlevel.barkbands.PCA.17                       36829 non-null  float64
#  181  lowlevel.barkbands.PCA.18                       36829 non-null  float64
#  182  lowlevel.barkbands.PCA.19                       36829 non-null  float64
#  183  lowlevel.barkbands.PCA.20                       36829 non-null  float64
#  184  lowlevel.barkbands.PCA.21                       36829 non-null  float64
#  185  lowlevel.barkbands.PCA.22                       36829 non-null  float64
#  186  lowlevel.barkbands.PCA.23                       36829 non-null  float64
#  187  lowlevel.barkbands.PCA.24                       36829 non-null  float64
#  188  lowlevel.barkbands.PCA.25                       36829 non-null  float64
#  189  lowlevel.barkbands.PCA.26                       36829 non-null  float64
#  190  lowlevel.barkbands.PCA.27                       36829 non-null  float64
#  191  lowlevel.barkbands.PCA.28                       36829 non-null  float64
#  192  lowlevel.barkbands.PCA.29                       36829 non-null  float64
#  193  lowlevel.barkbands.PCA.30                       36829 non-null  float64
#  194  lowlevel.barkbands.PCA.31                       36829 non-null  float64
#  195  lowlevel.barkbands.PCA.32                       36829 non-null  float64
#  196  lowlevel.barkbands.PCA.33                       36829 non-null  float64
#  197  lowlevel.barkbands.PCA.34                       36829 non-null  float64
#  198  lowlevel.barkbands.PCA.35                       36829 non-null  float64
#  199  lowlevel.barkbands.PCA.36                       36829 non-null  float64
#  200  lowlevel.barkbands.PCA.37                       36829 non-null  float64
#  201  lowlevel.barkbands.PCA.38                       36829 non-null  float64
#  202  lowlevel.barkbands.PCA.39                       36829 non-null  float64
#  203  lowlevel.barkbands.PCA.40                       36829 non-null  float64
#  204  lowlevel.barkbands.PCA.41                       36829 non-null  float64
#  205  lowlevel.barkbands.PCA.42                       36829 non-null  float64
#  206  lowlevel.barkbands.PCA.43                       36829 non-null  float64
#  207  lowlevel.barkbands.PCA.44                       36829 non-null  float64
#  208  lowlevel.barkbands.PCA.45                       36829 non-null  float64
#  209  lowlevel.barkbands.PCA.46                       36829 non-null  float64
#  210  lowlevel.barkbands.PCA.47                       36829 non-null  float64
#  211  lowlevel.barkbands.PCA.48                       36829 non-null  float64
#  212  lowlevel.barkbands.PCA.49                       36829 non-null  float64
#  213  lowlevel.barkbands.PCA.50                       36829 non-null  float64
#  214  lowlevel.barkbands.PCA.51                       36829 non-null  float64
#  215  lowlevel.barkbands.PCA.52                       36829 non-null  float64
#  216  lowlevel.barkbands.PCA.53                       36829 non-null  float64
#  217  lowlevel.barkbands.PCA.54                       36829 non-null  float64
#  218  lowlevel.barkbands.PCA.55                       36829 non-null  float64
#  219  lowlevel.barkbands.PCA.56                       36829 non-null  float64
#  220  lowlevel.barkbands.PCA.57                       36829 non-null  float64
#  221  lowlevel.barkbands.PCA.58                       36829 non-null  float64
#  222  lowlevel.barkbands.PCA.59                       36829 non-null  float64
#  223  lowlevel.barkbands.PCA.60                       36829 non-null  float64
#  224  lowlevel.erbbands.PCA.0                         36829 non-null  float64
#  225  lowlevel.erbbands.PCA.1                         36829 non-null  float64
#  226  lowlevel.erbbands.PCA.2                         36829 non-null  float64
#  227  lowlevel.erbbands.PCA.3                         36829 non-null  float64
#  228  lowlevel.erbbands.PCA.4                         36829 non-null  float64
#  229  lowlevel.erbbands.PCA.5                         36829 non-null  float64
#  230  lowlevel.erbbands.PCA.6                         36829 non-null  float64
#  231  lowlevel.erbbands.PCA.7                         36829 non-null  float64
#  232  lowlevel.erbbands.PCA.8                         36829 non-null  float64
#  233  lowlevel.erbbands.PCA.9                         36829 non-null  float64
#  234  lowlevel.erbbands.PCA.10                        36829 non-null  float64
#  235  lowlevel.erbbands.PCA.11                        36829 non-null  float64
#  236  lowlevel.erbbands.PCA.12                        36829 non-null  float64
#  237  lowlevel.erbbands.PCA.13                        36829 non-null  float64
#  238  lowlevel.erbbands.PCA.14                        36829 non-null  float64
#  239  lowlevel.erbbands.PCA.15                        36829 non-null  float64
#  240  lowlevel.erbbands.PCA.16                        36829 non-null  float64
#  241  lowlevel.erbbands.PCA.17                        36829 non-null  float64
#  242  lowlevel.erbbands.PCA.18                        36829 non-null  float64
#  243  lowlevel.erbbands.PCA.19                        36829 non-null  float64
#  244  lowlevel.erbbands.PCA.20                        36829 non-null  float64
#  245  lowlevel.erbbands.PCA.21                        36829 non-null  float64
#  246  lowlevel.erbbands.PCA.22                        36829 non-null  float64
#  247  lowlevel.erbbands.PCA.23                        36829 non-null  float64
#  248  lowlevel.erbbands.PCA.24                        36829 non-null  float64
#  249  lowlevel.erbbands.PCA.25                        36829 non-null  float64
#  250  lowlevel.erbbands.PCA.26                        36829 non-null  float64
#  251  lowlevel.erbbands.PCA.27                        36829 non-null  float64
#  252  lowlevel.erbbands.PCA.28                        36829 non-null  float64
#  253  lowlevel.erbbands.PCA.29                        36829 non-null  float64
#  254  lowlevel.erbbands.PCA.30                        36829 non-null  float64
#  255  lowlevel.erbbands.PCA.31                        36829 non-null  float64
#  256  lowlevel.erbbands.PCA.32                        36829 non-null  float64
#  257  lowlevel.erbbands.PCA.33                        36829 non-null  float64
#  258  lowlevel.erbbands.PCA.34                        36829 non-null  float64
#  259  lowlevel.erbbands.PCA.35                        36829 non-null  float64
#  260  lowlevel.erbbands.PCA.36                        36829 non-null  float64
#  261  lowlevel.erbbands.PCA.37                        36829 non-null  float64
#  262  lowlevel.erbbands.PCA.38                        36829 non-null  float64
#  263  lowlevel.erbbands.PCA.39                        36829 non-null  float64
#  264  lowlevel.erbbands.PCA.40                        36829 non-null  float64
#  265  lowlevel.erbbands.PCA.41                        36829 non-null  float64
#  266  lowlevel.erbbands.PCA.42                        36829 non-null  float64
#  267  lowlevel.erbbands.PCA.43                        36829 non-null  float64
#  268  lowlevel.erbbands.PCA.44                        36829 non-null  float64
#  269  lowlevel.erbbands.PCA.45                        36829 non-null  float64
#  270  lowlevel.erbbands.PCA.46                        36829 non-null  float64
#  271  lowlevel.erbbands.PCA.47                        36829 non-null  float64
#  272  lowlevel.erbbands.PCA.48                        36829 non-null  float64
#  273  lowlevel.erbbands.PCA.49                        36829 non-null  float64
#  274  lowlevel.erbbands.PCA.50                        36829 non-null  float64
#  275  lowlevel.erbbands.PCA.51                        36829 non-null  float64
#  276  lowlevel.erbbands.PCA.52                        36829 non-null  float64
#  277  lowlevel.erbbands.PCA.53                        36829 non-null  float64
#  278  lowlevel.erbbands.PCA.54                        36829 non-null  float64
#  279  lowlevel.erbbands.PCA.55                        36829 non-null  float64
#  280  lowlevel.erbbands.PCA.56                        36829 non-null  float64
#  281  lowlevel.erbbands.PCA.57                        36829 non-null  float64
#  282  lowlevel.erbbands.PCA.58                        36829 non-null  float64
#  283  lowlevel.erbbands.PCA.59                        36829 non-null  float64
#  284  lowlevel.erbbands.PCA.60                        36829 non-null  float64
#  285  lowlevel.erbbands.PCA.61                        36829 non-null  float64
#  286  lowlevel.erbbands.PCA.62                        36829 non-null  float64
#  287  lowlevel.erbbands.PCA.63                        36829 non-null  float64
#  288  lowlevel.erbbands.PCA.64                        36829 non-null  float64
#  289  lowlevel.erbbands.PCA.65                        36829 non-null  float64
#  290  lowlevel.erbbands.PCA.66                        36829 non-null  float64
#  291  lowlevel.erbbands.PCA.67                        36829 non-null  float64
#  292  lowlevel.erbbands.PCA.68                        36829 non-null  float64
#  293  lowlevel.erbbands.PCA.69                        36829 non-null  float64
#  294  lowlevel.erbbands.PCA.70                        36829 non-null  float64
#  295  lowlevel.gfcc.cov.PCA.0                         36829 non-null  float64
#  296  lowlevel.gfcc.cov.PCA.1                         36829 non-null  float64
#  297  lowlevel.gfcc.cov.PCA.2                         36829 non-null  float64
#  298  lowlevel.gfcc.cov.PCA.3                         36829 non-null  float64
#  299  lowlevel.gfcc.cov.PCA.4                         36829 non-null  float64
#  300  lowlevel.gfcc.cov.PCA.5                         36829 non-null  float64
#  301  lowlevel.gfcc.cov.PCA.6                         36829 non-null  float64
#  302  lowlevel.gfcc.cov.PCA.7                         36829 non-null  float64
#  303  lowlevel.gfcc.cov.PCA.8                         36829 non-null  float64
#  304  lowlevel.gfcc.cov.PCA.9                         36829 non-null  float64
#  305  lowlevel.gfcc.cov.PCA.10                        36829 non-null  float64
#  306  lowlevel.gfcc.cov.PCA.11                        36829 non-null  float64
#  307  lowlevel.gfcc.cov.PCA.12                        36829 non-null  float64
#  308  lowlevel.gfcc.cov.PCA.13                        36829 non-null  float64
#  309  lowlevel.gfcc.cov.PCA.14                        36829 non-null  float64
#  310  lowlevel.gfcc.cov.PCA.15                        36829 non-null  float64
#  311  lowlevel.gfcc.cov.PCA.16                        36829 non-null  float64
#  312  lowlevel.gfcc.cov.PCA.17                        36829 non-null  float64
#  313  lowlevel.gfcc.cov.PCA.18                        36829 non-null  float64
#  314  lowlevel.gfcc.cov.PCA.19                        36829 non-null  float64
#  315  lowlevel.gfcc.cov.PCA.20                        36829 non-null  float64
#  316  lowlevel.gfcc.cov.PCA.21                        36829 non-null  float64
#  317  lowlevel.gfcc.cov.PCA.22                        36829 non-null  float64
#  318  lowlevel.gfcc.cov.PCA.23                        36829 non-null  float64
#  319  lowlevel.gfcc.cov.PCA.24                        36829 non-null  float64
#  320  lowlevel.gfcc.cov.PCA.25                        36829 non-null  float64
#  321  lowlevel.gfcc.cov.PCA.26                        36829 non-null  float64
#  322  lowlevel.gfcc.cov.PCA.27                        36829 non-null  float64
#  323  lowlevel.gfcc.cov.PCA.28                        36829 non-null  float64
#  324  lowlevel.gfcc.cov.PCA.29                        36829 non-null  float64
#  325  lowlevel.gfcc.cov.PCA.30                        36829 non-null  float64
#  326  lowlevel.gfcc.cov.PCA.31                        36829 non-null  float64
#  327  lowlevel.gfcc.cov.PCA.32                        36829 non-null  float64
#  328  lowlevel.gfcc.cov.PCA.33                        36829 non-null  float64
#  329  lowlevel.gfcc.cov.PCA.34                        36829 non-null  float64
#  330  lowlevel.gfcc.cov.PCA.35                        36829 non-null  float64
#  331  lowlevel.gfcc.cov.PCA.36                        36829 non-null  float64
#  332  lowlevel.gfcc.cov.PCA.37                        36829 non-null  float64
#  333  lowlevel.gfcc.cov.PCA.38                        36829 non-null  float64
#  334  lowlevel.gfcc.cov.PCA.39                        36829 non-null  float64
#  335  lowlevel.gfcc.icov.PCA.0                        36829 non-null  float64
#  336  lowlevel.gfcc.icov.PCA.1                        36829 non-null  float64
#  337  lowlevel.gfcc.icov.PCA.2                        36829 non-null  float64
#  338  lowlevel.gfcc.icov.PCA.3                        36829 non-null  float64
#  339  lowlevel.gfcc.icov.PCA.4                        36829 non-null  float64
#  340  lowlevel.gfcc.icov.PCA.5                        36829 non-null  float64
#  341  lowlevel.gfcc.icov.PCA.6                        36829 non-null  float64
#  342  lowlevel.gfcc.icov.PCA.7                        36829 non-null  float64
#  343  lowlevel.gfcc.icov.PCA.8                        36829 non-null  float64
#  344  lowlevel.gfcc.icov.PCA.9                        36829 non-null  float64
#  345  lowlevel.gfcc.icov.PCA.10                       36829 non-null  float64
#  346  lowlevel.gfcc.icov.PCA.11                       36829 non-null  float64
#  347  lowlevel.gfcc.icov.PCA.12                       36829 non-null  float64
#  348  lowlevel.gfcc.icov.PCA.13                       36829 non-null  float64
#  349  lowlevel.gfcc.icov.PCA.14                       36829 non-null  float64
#  350  lowlevel.gfcc.icov.PCA.15                       36829 non-null  float64
#  351  lowlevel.gfcc.icov.PCA.16                       36829 non-null  float64
#  352  lowlevel.gfcc.icov.PCA.17                       36829 non-null  float64
#  353  lowlevel.gfcc.mean.PCA.0                        36829 non-null  float64
#  354  lowlevel.gfcc.mean.PCA.1                        36829 non-null  float64
#  355  lowlevel.gfcc.mean.PCA.2                        36829 non-null  float64
#  356  lowlevel.gfcc.mean.PCA.3                        36829 non-null  float64
#  357  lowlevel.gfcc.mean.PCA.4                        36829 non-null  float64
#  358  lowlevel.gfcc.mean.PCA.5                        36829 non-null  float64
#  359  lowlevel.gfcc.mean.PCA.6                        36829 non-null  float64
#  360  lowlevel.gfcc.mean.PCA.7                        36829 non-null  float64
#  361  lowlevel.gfcc.mean.PCA.8                        36829 non-null  float64
#  362  lowlevel.melbands.PCA.0                         36829 non-null  float64
#  363  lowlevel.melbands.PCA.1                         36829 non-null  float64
#  364  lowlevel.melbands.PCA.3                         36829 non-null  float64
#  365  lowlevel.melbands.PCA.4                         36829 non-null  float64
#  366  lowlevel.melbands.PCA.5                         36829 non-null  float64
#  367  lowlevel.melbands.PCA.6                         36829 non-null  float64
#  368  lowlevel.melbands.PCA.7                         36829 non-null  float64
#  369  lowlevel.melbands.PCA.8                         36829 non-null  float64
#  370  lowlevel.melbands.PCA.9                         36829 non-null  float64
#  371  lowlevel.melbands.PCA.10                        36829 non-null  float64
#  372  lowlevel.melbands.PCA.11                        36829 non-null  float64
#  373  lowlevel.melbands.PCA.12                        36829 non-null  float64
#  374  lowlevel.melbands.PCA.13                        36829 non-null  float64
#  375  lowlevel.melbands.PCA.14                        36829 non-null  float64
#  376  lowlevel.melbands.PCA.15                        36829 non-null  float64
#  377  lowlevel.melbands.PCA.16                        36829 non-null  float64
#  378  lowlevel.melbands.PCA.17                        36829 non-null  float64
#  379  lowlevel.melbands.PCA.18                        36829 non-null  float64
#  380  lowlevel.melbands.PCA.19                        36829 non-null  float64
#  381  lowlevel.melbands.PCA.20                        36829 non-null  float64
#  382  lowlevel.melbands.PCA.21                        36829 non-null  float64
#  383  lowlevel.melbands.PCA.22                        36829 non-null  float64
#  384  lowlevel.melbands.PCA.23                        36829 non-null  float64
#  385  lowlevel.melbands.PCA.24                        36829 non-null  float64
#  386  lowlevel.melbands.PCA.25                        36829 non-null  float64
#  387  lowlevel.melbands.PCA.26                        36829 non-null  float64
#  388  lowlevel.melbands.PCA.27                        36829 non-null  float64
#  389  lowlevel.melbands.PCA.28                        36829 non-null  float64
#  390  lowlevel.melbands.PCA.29                        36829 non-null  float64
#  391  lowlevel.melbands.PCA.30                        36829 non-null  float64
#  392  lowlevel.melbands.PCA.31                        36829 non-null  float64
#  393  lowlevel.melbands.PCA.32                        36829 non-null  float64
#  394  lowlevel.melbands.PCA.33                        36829 non-null  float64
#  395  lowlevel.melbands.PCA.34                        36829 non-null  float64
#  396  lowlevel.melbands.PCA.35                        36829 non-null  float64
#  397  lowlevel.melbands.PCA.36                        36829 non-null  float64
#  398  lowlevel.melbands.PCA.37                        36829 non-null  float64
#  399  lowlevel.melbands.PCA.38                        36829 non-null  float64
#  400  lowlevel.melbands.PCA.39                        36829 non-null  float64
#  401  lowlevel.melbands.PCA.40                        36829 non-null  float64
#  402  lowlevel.melbands.PCA.41                        36829 non-null  float64
#  403  lowlevel.melbands.PCA.42                        36829 non-null  float64
#  404  lowlevel.melbands.PCA.43                        36829 non-null  float64
#  405  lowlevel.melbands.PCA.44                        36829 non-null  float64
#  406  lowlevel.melbands.PCA.45                        36829 non-null  float64
#  407  lowlevel.melbands.PCA.46                        36829 non-null  float64
#  408  lowlevel.melbands.PCA.47                        36829 non-null  float64
#  409  lowlevel.melbands.PCA.48                        36829 non-null  float64
#  410  lowlevel.melbands.PCA.49                        36829 non-null  float64
#  411  lowlevel.melbands.PCA.50                        36829 non-null  float64
#  412  lowlevel.melbands.PCA.51                        36829 non-null  float64
#  413  lowlevel.melbands.PCA.52                        36829 non-null  float64
#  414  lowlevel.melbands.PCA.53                        36829 non-null  float64
#  415  lowlevel.melbands.PCA.54                        36829 non-null  float64
#  416  lowlevel.melbands.PCA.55                        36829 non-null  float64
#  417  lowlevel.melbands.PCA.56                        36829 non-null  float64
#  418  lowlevel.melbands.PCA.57                        36829 non-null  float64
#  419  lowlevel.melbands.PCA.58                        36829 non-null  float64
#  420  lowlevel.melbands.PCA.59                        36829 non-null  float64
#  421  lowlevel.melbands.PCA.60                        36829 non-null  float64
#  422  lowlevel.melbands.PCA.61                        36829 non-null  float64
#  423  lowlevel.melbands.PCA.62                        36829 non-null  float64
#  424  lowlevel.melbands.PCA.63                        36829 non-null  float64
#  425  lowlevel.melbands.PCA.64                        36829 non-null  float64
#  426  lowlevel.melbands.PCA.65                        36829 non-null  float64
#  427  lowlevel.melbands.PCA.66                        36829 non-null  float64
#  428  lowlevel.melbands.PCA.67                        36829 non-null  float64
#  429  lowlevel.melbands.PCA.68                        36829 non-null  float64
#  430  lowlevel.melbands.PCA.69                        36829 non-null  float64
#  431  lowlevel.melbands.PCA.70                        36829 non-null  float64
#  432  lowlevel.melbands.PCA.71                        36829 non-null  float64
#  433  lowlevel.mfcc.cov.PCA.0                         36829 non-null  float64
#  434  lowlevel.mfcc.cov.PCA.1                         36829 non-null  float64
#  435  lowlevel.mfcc.cov.PCA.2                         36829 non-null  float64
#  436  lowlevel.mfcc.cov.PCA.3                         36829 non-null  float64
#  437  lowlevel.mfcc.cov.PCA.4                         36829 non-null  float64
#  438  lowlevel.mfcc.cov.PCA.5                         36829 non-null  float64
#  439  lowlevel.mfcc.cov.PCA.6                         36829 non-null  float64
#  440  lowlevel.mfcc.cov.PCA.7                         36829 non-null  float64
#  441  lowlevel.mfcc.cov.PCA.8                         36829 non-null  float64
#  442  lowlevel.mfcc.cov.PCA.9                         36829 non-null  float64
#  443  lowlevel.mfcc.cov.PCA.10                        36829 non-null  float64
#  444  lowlevel.mfcc.cov.PCA.11                        36829 non-null  float64
#  445  lowlevel.mfcc.cov.PCA.12                        36829 non-null  float64
#  446  lowlevel.mfcc.cov.PCA.13                        36829 non-null  float64
#  447  lowlevel.mfcc.cov.PCA.14                        36829 non-null  float64
#  448  lowlevel.mfcc.cov.PCA.15                        36829 non-null  float64
#  449  lowlevel.mfcc.cov.PCA.16                        36829 non-null  float64
#  450  lowlevel.mfcc.cov.PCA.17                        36829 non-null  float64
#  451  lowlevel.mfcc.cov.PCA.18                        36829 non-null  float64
#  452  lowlevel.mfcc.cov.PCA.19                        36829 non-null  float64
#  453  lowlevel.mfcc.cov.PCA.20                        36829 non-null  float64
#  454  lowlevel.mfcc.cov.PCA.21                        36829 non-null  float64
#  455  lowlevel.mfcc.cov.PCA.22                        36829 non-null  float64
#  456  lowlevel.mfcc.cov.PCA.23                        36829 non-null  float64
#  457  lowlevel.mfcc.cov.PCA.24                        36829 non-null  float64
#  458  lowlevel.mfcc.cov.PCA.25                        36829 non-null  float64
#  459  lowlevel.mfcc.cov.PCA.26                        36829 non-null  float64
#  460  lowlevel.mfcc.cov.PCA.27                        36829 non-null  float64
#  461  lowlevel.mfcc.cov.PCA.28                        36829 non-null  float64
#  462  lowlevel.mfcc.cov.PCA.29                        36829 non-null  float64
#  463  lowlevel.mfcc.cov.PCA.30                        36829 non-null  float64
#  464  lowlevel.mfcc.cov.PCA.31                        36829 non-null  float64
#  465  lowlevel.mfcc.cov.PCA.32                        36829 non-null  float64
#  466  lowlevel.mfcc.cov.PCA.33                        36829 non-null  float64
#  467  lowlevel.mfcc.cov.PCA.34                        36829 non-null  float64
#  468  lowlevel.mfcc.cov.PCA.35                        36829 non-null  float64
#  469  lowlevel.mfcc.icov.PCA.0                        36829 non-null  float64
#  470  lowlevel.mfcc.icov.PCA.1                        36829 non-null  float64
#  471  lowlevel.mfcc.icov.PCA.2                        36829 non-null  float64
#  472  lowlevel.mfcc.mean.PCA.0                        36829 non-null  float64
#  473  lowlevel.mfcc.mean.PCA.1                        36829 non-null  float64
#  474  lowlevel.mfcc.mean.PCA.2                        36829 non-null  float64
#  475  lowlevel.mfcc.mean.PCA.3                        36829 non-null  float64
#  476  lowlevel.mfcc.mean.PCA.4                        36829 non-null  float64
#  477  lowlevel.mfcc.mean.PCA.5                        36829 non-null  float64
#  478  lowlevel.mfcc.mean.PCA.6                        36829 non-null  float64
#  479  lowlevel.mfcc.mean.PCA.7                        36829 non-null  float64
#  480  lowlevel.mfcc.mean.PCA.8                        36829 non-null  float64
#  481  lowlevel.mfcc.mean.PCA.9                        36829 non-null  float64
#  482  lowlevel.spectral_contrast_coeffs.PCA.0         36829 non-null  float64
#  483  lowlevel.spectral_contrast_coeffs.PCA.1         36829 non-null  float64
#  484  lowlevel.spectral_contrast_coeffs.PCA.2         36829 non-null  float64
#  485  lowlevel.spectral_contrast_coeffs.PCA.3         36829 non-null  float64
#  486  lowlevel.spectral_contrast_coeffs.PCA.4         36829 non-null  float64
#  487  lowlevel.spectral_contrast_coeffs.PCA.5         36829 non-null  float64
#  488  lowlevel.spectral_contrast_coeffs.PCA.6         36829 non-null  float64
#  489  lowlevel.spectral_contrast_coeffs.PCA.7         36829 non-null  float64
#  490  lowlevel.spectral_contrast_coeffs.PCA.8         36829 non-null  float64
#  491  lowlevel.spectral_contrast_coeffs.PCA.9         36829 non-null  float64
#  492  lowlevel.spectral_contrast_coeffs.PCA.10        36829 non-null  float64
#  493  lowlevel.spectral_contrast_coeffs.PCA.11        36829 non-null  float64
#  494  lowlevel.spectral_contrast_coeffs.PCA.12        36829 non-null  float64
#  495  lowlevel.spectral_contrast_coeffs.PCA.13        36829 non-null  float64
#  496  lowlevel.spectral_contrast_valleys.PCA.0        36829 non-null  float64
#  497  lowlevel.spectral_contrast_valleys.PCA.1        36829 non-null  float64
#  498  lowlevel.spectral_contrast_valleys.PCA.2        36829 non-null  float64
#  499  lowlevel.spectral_contrast_valleys.PCA.3        36829 non-null  float64
#  500  lowlevel.spectral_contrast_valleys.PCA.4        36829 non-null  float64
#  501  lowlevel.spectral_contrast_valleys.PCA.5        36829 non-null  float64
#  502  lowlevel.spectral_contrast_valleys.PCA.6        36829 non-null  float64
#  503  lowlevel.spectral_contrast_valleys.PCA.7        36829 non-null  float64
#  504  lowlevel.spectral_contrast_valleys.PCA.8        36829 non-null  float64
#  505  lowlevel.spectral_contrast_valleys.PCA.9        36829 non-null  float64
#  506  rhythm.beats_loudness_band_ratio.PCA.0          36829 non-null  float64
#  507  rhythm.beats_loudness_band_ratio.PCA.1          36829 non-null  float64
#  508  rhythm.beats_loudness_band_ratio.PCA.2          36829 non-null  float64
#  509  rhythm.beats_loudness_band_ratio.PCA.3          36829 non-null  float64
#  510  rhythm.beats_loudness_band_ratio.PCA.4          36829 non-null  float64
#  511  rhythm.beats_loudness_band_ratio.PCA.5          36829 non-null  float64
#  512  rhythm.beats_loudness_band_ratio.PCA.6          36829 non-null  float64
#  513  rhythm.beats_loudness_band_ratio.PCA.7          36829 non-null  float64
#  514  rhythm.beats_loudness_band_ratio.PCA.8          36829 non-null  float64
#  515  rhythm.beats_loudness_band_ratio.PCA.9          36829 non-null  float64
#  516  rhythm.beats_loudness_band_ratio.PCA.10         36829 non-null  float64
#  517  rhythm.beats_loudness_band_ratio.PCA.11         36829 non-null  float64
#  518  rhythm.beats_loudness_band_ratio.PCA.12         36829 non-null  float64
#  519  rhythm.beats_loudness_band_ratio.PCA.13         36829 non-null  float64
#  520  rhythm.beats_loudness_band_ratio.PCA.14         36829 non-null  float64
#  521  rhythm.beats_loudness_band_ratio.PCA.15         36829 non-null  float64
#  522  rhythm.beats_loudness_band_ratio.PCA.16         36829 non-null  float64
#  523  tonal.chords_histogram.PCA.0                    36829 non-null  float64
#  524  tonal.chords_histogram.PCA.1                    36829 non-null  float64
#  525  tonal.chords_histogram.PCA.2                    36829 non-null  float64
#  526  tonal.chords_histogram.PCA.3                    36829 non-null  float64
#  527  tonal.chords_histogram.PCA.4                    36829 non-null  float64
#  528  tonal.chords_histogram.PCA.5                    36829 non-null  float64
#  529  tonal.chords_histogram.PCA.6                    36829 non-null  float64
#  530  tonal.chords_histogram.PCA.7                    36829 non-null  float64
#  531  tonal.chords_histogram.PCA.8                    36829 non-null  float64
#  532  tonal.chords_histogram.PCA.9                    36829 non-null  float64
#  533  tonal.chords_histogram.PCA.10                   36829 non-null  float64
#  534  tonal.chords_histogram.PCA.11                   36829 non-null  float64
#  535  tonal.chords_histogram.PCA.12                   36829 non-null  float64
#  536  tonal.chords_histogram.PCA.13                   36829 non-null  float64
#  537  tonal.chords_histogram.PCA.14                   36829 non-null  float64
#  538  tonal.chords_histogram.PCA.15                   36829 non-null  float64
#  539  tonal.chords_histogram.PCA.16                   36829 non-null  float64
#  540  tonal.chords_histogram.PCA.17                   36829 non-null  float64
#  541  tonal.chords_histogram.PCA.18                   36829 non-null  float64
#  542  tonal.hpcp.PCA.0                                36829 non-null  float64
#  543  tonal.hpcp.PCA.1                                36829 non-null  float64
#  544  tonal.hpcp.PCA.2                                36829 non-null  float64
#  545  tonal.hpcp.PCA.3                                36829 non-null  float64
#  546  tonal.hpcp.PCA.4                                36829 non-null  float64
#  547  tonal.hpcp.PCA.5                                36829 non-null  float64
#  548  tonal.hpcp.PCA.6                                36829 non-null  float64
#  549  tonal.hpcp.PCA.7                                36829 non-null  float64
#  550  tonal.hpcp.PCA.8                                36829 non-null  float64
#  551  tonal.hpcp.PCA.9                                36829 non-null  float64
#  552  tonal.hpcp.PCA.10                               36829 non-null  float64
#  553  tonal.hpcp.PCA.11                               36829 non-null  float64
#  554  tonal.hpcp.PCA.12                               36829 non-null  float64
#  555  tonal.hpcp.PCA.13                               36829 non-null  float64
#  556  tonal.hpcp.PCA.14                               36829 non-null  float64
#  557  tonal.hpcp.PCA.15                               36829 non-null  float64
#  558  tonal.hpcp.PCA.16                               36829 non-null  float64
#  559  tonal.hpcp.PCA.17                               36829 non-null  float64
#  560  tonal.hpcp.PCA.18                               36829 non-null  float64
#  561  tonal.hpcp.PCA.19                               36829 non-null  float64
#  562  tonal.hpcp.PCA.20                               36829 non-null  float64
#  563  tonal.hpcp.PCA.21                               36829 non-null  float64
#  564  tonal.hpcp.PCA.22                               36829 non-null  float64
#  565  tonal.hpcp.PCA.23                               36829 non-null  float64
#  566  tonal.hpcp.PCA.24                               36829 non-null  float64
#  567  tonal.hpcp.PCA.25                               36829 non-null  float64
#  568  tonal.hpcp.PCA.26                               36829 non-null  float64
#  569  tonal.hpcp.PCA.27                               36829 non-null  float64
#  570  tonal.hpcp.PCA.28                               36829 non-null  float64
#  571  tonal.hpcp.PCA.29                               36829 non-null  float64
#  572  tonal.hpcp.PCA.30                               36829 non-null  float64
#  573  tonal.hpcp.PCA.31                               36829 non-null  float64
#  574  tonal.hpcp.PCA.32                               36829 non-null  float64
#  575  tonal.hpcp.PCA.33                               36829 non-null  float64
#  576  tonal.hpcp.PCA.34                               36829 non-null  float64
#  577  tonal.hpcp.PCA.35                               36829 non-null  float64
#  578  tonal.hpcp.PCA.36                               36829 non-null  float64
#  579  tonal.hpcp.PCA.37                               36829 non-null  float64
#  580  tonal.hpcp.PCA.38                               36829 non-null  float64
#  581  tonal.hpcp.PCA.39                               36829 non-null  float64
#  582  tonal.hpcp.PCA.40                               36829 non-null  float64
#  583  tonal.hpcp.PCA.41                               36829 non-null  float64
#  584  tonal.hpcp.PCA.42                               36829 non-null  float64
#  585  tonal.hpcp.PCA.43                               36829 non-null  float64
#  586  tonal.hpcp.PCA.44                               36829 non-null  float64
#  587  tonal.hpcp.PCA.45                               36829 non-null  float64
#  588  tonal.hpcp.PCA.46                               36829 non-null  float64
#  589  tonal.hpcp.PCA.47                               36829 non-null  float64
#  590  tonal.hpcp.PCA.48                               36829 non-null  float64
#  591  tonal.thpcp.PCA.0                               36829 non-null  float64
#  592  tonal.thpcp.PCA.1                               36829 non-null  float64
#  593  tonal.thpcp.PCA.2                               36829 non-null  float64
#  594  tonal.thpcp.PCA.3                               36829 non-null  float64
#  595  tonal.thpcp.PCA.4                               36829 non-null  float64
#  596  tonal.thpcp.PCA.5                               36829 non-null  float64
#  597  tonal.thpcp.PCA.6                               36829 non-null  float64
#  598  tonal.thpcp.PCA.7                               36829 non-null  float64
#  599  tonal.thpcp.PCA.8                               36829 non-null  float64
#  600  tonal.thpcp.PCA.9                               36829 non-null  float64
#  601  tonal.thpcp.PCA.10                              36829 non-null  float64
#  602  tonal.thpcp.PCA.11                              36829 non-null  float64
#  603  mbdata.id                                       36829 non-null  object
#  604  mbdata.title                                    36829 non-null  object
#  605  mbdata.artist-name                              36829 non-null  object
#  606  mbdata.artist-id                                36829 non-null  object
#  607  mbdata.all-tags                                 36829 non-null  object
#  608  mbdata.genre                                    36829 non-null  object
#  609  mbdata.techno                                   36829 non-null  bool
#  610  mbdata.house                                    36829 non-null  bool
#  611  mbdata.trance                                   36829 non-null  bool
#  612  mbdata.dnb                                      36829 non-null  bool
# dtypes: bool(4), float64(603), object(6)
# memory usage: 171.3+ MB

# %%
# preparing the data to be fed into our model
labels = ['mbdata.techno', 'mbdata.house', 'mbdata.trance', 'mbdata.dnb']
drop_cols = ['mbdata.id', 'mbdata.title', 'mbdata.artist-name', 'mbdata.artist-id',
             'mbdata.all-tags', 'mbdata.genre']

X1 = df1.drop(columns=drop_cols+labels)
y1 = df1[labels]
X2 = df2.drop(columns=drop_cols+labels)
y2 = df2[labels]
X3 = df3.drop(columns=drop_cols+labels)
y3 = df3[labels]

# %%
# train test split
from sklearn.model_selection import train_test_split

X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.2, random_state=415)
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.2, random_state=415)
X3_train, X3_test, y3_train, y3_test = train_test_split(X3, y3, test_size=0.2, random_state=415)

# %% [markdown]
# List of Models to Consider:
# - XGBClassifier
# - RandomForestClassifier
# - SVM
# - Naive Bayes
#
# Performance Metrics
# - Accuracy (not exact match)
# - Precision/ Recall/ F1-Score
# - Hamming Loss

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.multioutput import MultiOutputClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import hamming_loss
from sklearn.metrics import jaccard_score

# %%
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
multi_rf_classifier = MultiOutputClassifier(rf_classifier, n_jobs=-1)
multi_rf_classifier.fit(X2_train, y2_train)
# Out:
# MultiOutputClassifier(estimator=RandomForestClassifier(random_state=42),
#                       n_jobs=-1)

# %%
y2_pred = multi_rf_classifier.predict(X2_test)
for i, label in enumerate(y2.columns):
    print(f"Label: {label}")
    print(classification_report(y2_test.iloc[:, i], y2_pred[:, i]))

# %%
# Performing a RandomSearchCV for hyperparameter tuning

from sklearn.model_selection import RandomizedSearchCV

base_estimator = RandomForestClassifier(random_state=42)

param_distributions = {
    'estimator__n_estimators': [100, 200, 500],
    'estimator__max_depth': [None, 10, 20],
    'estimator__min_samples_split': [2, 5, 10],
    'estimator__min_samples_leaf': [1, 2, 4],
    'estimator__max_features': ['auto', 'sqrt', 'log2']
}

multi_output_model = MultiOutputClassifier(base_estimator, n_jobs=-1)


random_search = RandomizedSearchCV(estimator=multi_output_model, 
                                   param_distributions=param_distributions, 
                                   n_iter=10, cv=3, verbose=2, n_jobs=-1, random_state=42)
random_search.fit(X2_train, y2_train)

print(random_search.best_params_)

# %%
# Using the model with best_params

best_model = random_search.best_estimator_
y2_pred = best_model.predict(X2_test)

# %%
(y2_test == y2_pred).values.flatten().mean()
# Out:
# 0.8196103719793646

# %%
hamming_loss(y2_test, y2_pred)
# Out:
# 0.18038962802063535

# %%
accuracy = accuracy_score(y2_test, y2_pred, normalize=True)
print(f'Accuracy: {accuracy}')
print(classification_report(y2_test, y2_pred, target_names=labels))
# Out:
# Accuracy: 0.46592451805593266
#                precision    recall  f1-score   support
#
# mbdata.techno       0.76      0.41      0.53      2207
#  mbdata.house       0.78      0.53      0.63      2943
# mbdata.trance       0.92      0.53      0.67      2111
#    mbdata.dnb       0.91      0.59      0.71      1769
#
#     micro avg       0.83      0.51      0.64      9030
#     macro avg       0.84      0.52      0.64      9030
#  weighted avg       0.83      0.51      0.63      9030
#   samples avg       0.60      0.55      0.56      9030
# c:\Users\kling\anaconda3\envs\erdos_may_2024\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ### XGBoost

# %%
import numpy as np
from sklearn.model_selection import RandomizedSearchCV
from sklearn.multioutput import MultiOutputClassifier
from xgboost import XGBClassifier

# %% [markdown]
# #### EDA Version 2

# %%
# Base estimator
xgb_model = XGBClassifier(objective='binary:logistic', eval_metric='logloss', use_label_encoder=False)

# Parameter grid for RandomizedSearchCV
param_distributions = {
    'estimator__n_estimators': [100, 200, 500],
    'estimator__max_depth': [3, 5, 7, 10],
    'estimator__learning_rate': [0.01, 0.1, 0.2],
    'estimator__subsample': [0.6, 0.8, 1.0],
    'estimator__colsample_bytree': [0.6, 0.8, 1.0]
}

# Wrap XGBClassifier with MultiOutputClassifier
multi_output_model = MultiOutputClassifier(xgb_model, n_jobs=-1)

# Set up RandomizedSearchCV
xgb_random_search = RandomizedSearchCV(
    estimator=multi_output_model,
    param_distributions=param_distributions,
    n_iter=10,  # Number of parameter settings sampled
    cv=3,  # 3-fold cross-validation
    verbose=2,  # Verbosity level
    n_jobs=-1,  # Use all processors
    random_state=42
)

# Fit RandomizedSearchCV to the training data
xgb_random_search.fit(X2_train, y2_train)

# Print the best parameters found by RandomizedSearchCV
print("Best Parameters:", random_search.best_params_)

# %%
xgb_model = XGBClassifier(
    booster = 'gbtree',
    learning_rate = 0.2,
    max_depth = 8,
    subsample = 0.8,
    objective = 'binary:logistic',
    num_class = 4
    )

clf = MultiOutputClassifier(xgb_model)

clf.fit(X2_train, y2_train)
# Out:
# MultiOutputClassifier(estimator=XGBClassifier(base_score=None, booster='gbtree',
#                                               callbacks=None,
#                                               colsample_bylevel=None,
#                                               colsample_bynode=None,
#                                               colsample_bytree=None,
#                                               device=None,
#                                               early_stopping_rounds=None,
#                                               enable_categorical=False,
#                                               eval_metric=None,
#                                               feature_types=None, gamma=None,
#                                               grow_policy=None,
#                                               importance_type=None,
#                                               interaction_constraints=None,
#                                               learning_rate=0.2, max_bin=None,
#                                               max_cat_threshold=None,
#                                               max_cat_to_onehot=None,
#                                               max_delta_step=None, max_depth=8,
#                                               max_leaves=None,
#                                               min_child_weight=None,
#                                               missing=nan,
#                                               monotone_constraints=None,
#                                               multi_strategy=None,
#                                               n_estimators=None, n_jobs=None,
#                                               num_class=4,
#                                               num_parallel_tree=None, ...))

# %%
# hyperparameter tuning
xgb_model = XGBClassifier()

param_dist = {
    'estimator__learning_rate': uniform(0.01, 0.2),
    'estimator__max_depth': randint(3, 10),
    'estimator__n_estimators': randint(50, 200),
    'estimator__subsample': uniform(0.8, 1.0),
    'estimator__colsample_bytree': uniform(0.8, 1.0)
}

random_search = RandomizedSearchCV(estimator=xgb_model, param_distributions=param_dist,
                                   n_iter=50, scoring='f1_weighted', cv=3, verbose=1, random_state=42)


random_search.fit(X2_train, y2_train)

best_params = random_search.best_params_
print("Best parameters found: ", best_params)

# %%
best_model = random_search.best_estimator_
y2_pred = best_model.predict(X2_test)

# %%
accuracy = (y2_pred == y2_test).mean()
accuracy
# Out:
# mbdata.techno    0.798670
# mbdata.house     0.768395
# mbdata.trance    0.876324
# mbdata.dnb       0.908363
# dtype: float64

# %%
from sklearn.metrics import classification_report
print(classification_report(y2_test, y2_pred, target_names=labels))
# Out:
#                precision    recall  f1-score   support
#
# mbdata.techno       0.71      0.52      0.60      2147
#  mbdata.house       0.74      0.67      0.70      2995
# mbdata.trance       0.84      0.70      0.76      2117
#    mbdata.dnb       0.85      0.75      0.80      1757
#
#     micro avg       0.78      0.66      0.71      9016
#     macro avg       0.78      0.66      0.72      9016
#  weighted avg       0.78      0.66      0.71      9016
#   samples avg       0.72      0.70      0.69      9016
# c:\Users\kling\anaconda3\envs\erdos_may_2024\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# trying without OnevsRest
xgb_model = XGBClassifier()
xgb_model.fit(X2_train, y2_train)
y2_pred = xgb_model.predict(X2_test)

# %%
accuracy = (y2_pred == y2_test).mean()
accuracy
# Out:
# mbdata.techno    0.797719
# mbdata.house     0.761472
# mbdata.trance    0.873880
# mbdata.dnb       0.906462
# dtype: float64

# %%
report = classification_report(y2_test, y2_pred, target_names=['techno', 'house', 'trance', 'dnb'])
print(report)
# Out:
#               precision    recall  f1-score   support
#
#       techno       0.70      0.54      0.61      2147
#        house       0.73      0.66      0.69      2995
#       trance       0.84      0.70      0.76      2117
#          dnb       0.84      0.75      0.79      1757
#
#    micro avg       0.77      0.66      0.71      9016
#    macro avg       0.78      0.66      0.71      9016
# weighted avg       0.77      0.66      0.71      9016
#  samples avg       0.71      0.70      0.69      9016
# c:\Users\kling\anaconda3\envs\erdos_may_2024\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
logistic_model = LogisticRegression(solver='lbfgs', max_iter=1000)
multi_output_logi = MultiOutputClassifier(logistic_model, n_jobs=-1)
multi_output_logi.fit(X2_train, y2_train)
# Out:
# MultiOutputClassifier(estimator=LogisticRegression(max_iter=1000), n_jobs=-1)

# %%
y2_pred_logi = multi_output_logi.predict(X2_test.values)

# %%
(y2_test == y2_pred_logi).mean()
# Out:
# mbdata.techno    0.700380
# mbdata.house     0.600462
# mbdata.trance    0.713413
# mbdata.dnb       0.759843
# dtype: float64

# %%
(y2_test == y2_pred_logi).values.flatten().mean()
# Out:
# 0.6935243008417051

# %%
classification_report(y2_test, y2_pred_logi, zero_division=0, target_names=labels)
# Out:
# '               precision    recall  f1-score   support\n\nmbdata.techno       0.00      0.00      0.00      2207\n mbdata.house       0.00      0.00      0.00      2943\nmbdata.trance       0.00      0.00      0.00      2111\n   mbdata.dnb       0.00      0.00      0.00      1769\n\n    micro avg       0.00      0.00      0.00      9030\n    macro avg       0.00      0.00      0.00      9030\n weighted avg       0.00      0.00      0.00      9030\n  samples avg       0.00      0.00      0.00      9030\n'

# %%
# trying a different threshold
y2_pred_logi_prob = multi_output_logi.predict_proba(X2_test.values)
# Out:
# c:\Users\kling\anaconda3\envs\erdos_may_2024\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# c:\Users\kling\anaconda3\envs\erdos_may_2024\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# c:\Users\kling\anaconda3\envs\erdos_may_2024\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# c:\Users\kling\anaconda3\envs\erdos_may_2024\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
thresholds = [0.5, 0.5, 0.5, 0.5]

y2_pred_logi_thres = np.array([
    (probs[:, 1] >= thresholds[i]).astype(int)
    for i, probs in enumerate(y2_pred_logi_prob)
]).T

# %%
print((y2_pred_logi_thres == y2_test).mean())

print(classification_report(y2_test, y2_pred_logi_thres))
# Out:
# mbdata.techno    0.700380
# mbdata.house     0.600462
# mbdata.trance    0.713413
# mbdata.dnb       0.759843
# dtype: float64
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      2207
#            1       0.00      0.00      0.00      2943
#            2       0.00      0.00      0.00      2111
#            3       0.00      0.00      0.00      1769
#
#    micro avg       0.00      0.00      0.00      9030
#    macro avg       0.00      0.00      0.00      9030
# weighted avg       0.00      0.00      0.00      9030
#  samples avg       0.00      0.00      0.00      9030
# c:\Users\kling\anaconda3\envs\erdos_may_2024\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\kling\anaconda3\envs\erdos_may_2024\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\kling\anaconda3\envs\erdos_may_2024\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ### Random Guessing

# %%
def generate_weighted_random_predictions(X, label_probabilities):
    """
    Generate random binary predictions for multi-label classification based on label probabilities.
    
    Parameters:
    - X: DataFrame or array-like, shape (n_samples, n_features)
    - label_probabilities: list or array, shape (num_labels,), probabilities of each label being assigned
    
    Returns:
    - y_pred_weighted: array, shape (n_samples, num_labels)
    """
    num_samples = X.shape[0]
    num_labels = len(label_probabilities)
    
    # Generate random binary predictions based on label probabilities
    y_pred_weighted = np.zeros((num_samples, num_labels))
    
    for i in range(num_samples):
        for j in range(num_labels):
            if np.random.rand() < label_probabilities[j]:
                y_pred_weighted[i, j] = 1
    
    return y_pred_weighted

# %%
techno_pro = (y2['mbdata.techno'].sum())/len(y2)
house_pro = (y2['mbdata.house'].sum())/len(y2)
trance_pro = (y2['mbdata.trance'].sum())/len(y2)
dnb_pro = (y2['mbdata.dnb'].sum())/len(y2)

# %%
label_probabilities = [techno_pro, house_pro, trance_pro, dnb_pro]
y2_pred_rand = generate_weighted_random_predictions(X2_test, label_probabilities)

# %%
(y2_pred_rand == y2_test).mean()
# Out:
# mbdata.techno    0.576025
# mbdata.house     0.518463
# mbdata.trance    0.593402
# mbdata.dnb       0.638746
# dtype: float64

# %%
classification_report(y2_test, y2_pred_rand, target_names=labels)
# Out:
# c:\Users\kling\anaconda3\envs\erdos_may_2024\lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# '               precision    recall  f1-score   support\n\nmbdata.techno       0.29      0.29      0.29      2207\n mbdata.house       0.40      0.42      0.41      2943\nmbdata.trance       0.29      0.28      0.28      2111\n   mbdata.dnb       0.25      0.25      0.25      1769\n\n    micro avg       0.32      0.32      0.32      9030\n    macro avg       0.31      0.31      0.31      9030\n weighted avg       0.32      0.32      0.32      9030\n  samples avg       0.25      0.32      0.26      9030\n'

# %%
# removing features with three or more genres
num_genres = df2[labels].sum(axis=1)
df2_filtered = df2[num_genres < 3]

# %%
X2_f = df2_filtered.drop(columns=drop_cols+labels)
y2_f = df2_filtered[labels]

# %%
X2f_train, X2f_test, y2f_train, y2f_test = train_test_split(X2_f, y2_f, test_size=0.2, random_state=415)

# %%
xgb_model_f = XGBClassifier(
    subsample=1.0,
    n_estimators=200,
    max_depth=5,
    learning_rate=0.1,
    colsample_bytree=1.0,
    objective='binary:logistic',  # For multi-label classification, use 'binary:logistic'
    use_label_encoder=False,      # This disables the label encoder warning
    eval_metric='logloss'         # Common evaluation metric for binary classification
)

multi_output_xgb_f = MultiOutputClassifier(xgb_model_f, n_jobs=-1)

multi_output_xgb_f.fit(X2f_train, y2f_train)
# Out:
# MultiOutputClassifier(estimator=XGBClassifier(base_score=None, booster=None,
#                                               callbacks=None,
#                                               colsample_bylevel=None,
#                                               colsample_bynode=None,
#                                               colsample_bytree=1.0, device=None,
#                                               early_stopping_rounds=None,
#                                               enable_categorical=False,
#                                               eval_metric='logloss',
#                                               feature_types=None, gamma=None,
#                                               grow_policy=None,
#                                               importance_type=None,
#                                               interaction_constraints=None,
#                                               learning_rate=0.1, max_bin=None,
#                                               max_cat_threshold=None,
#                                               max_cat_to_onehot=None,
#                                               max_delta_step=None, max_depth=5,
#                                               max_leaves=None,
#                                               min_child_weight=None,
#                                               missing=nan,
#                                               monotone_constraints=None,
#                                               multi_strategy=None,
#                                               n_estimators=200, n_jobs=None,
#                                               num_parallel_tree=None,
#                                               random_state=None, ...),
#                       n_jobs=-1)

# %%
y2f_pred = multi_output_xgb_f.predict(X2f_test)

# %%
(y2f_pred == y2f_test).mean()
# Out:
# mbdata.techno    0.816443
# mbdata.house     0.779149
# mbdata.trance    0.882296
# mbdata.dnb       0.908499
# dtype: float64

# %%
print(classification_report(y2f_test, y2f_pred, zero_division=0, target_names=labels))
# Out:
#                precision    recall  f1-score   support
#
# mbdata.techno       0.74      0.54      0.62      2038
#  mbdata.house       0.75      0.67      0.71      2868
# mbdata.trance       0.85      0.70      0.77      1986
#    mbdata.dnb       0.84      0.74      0.79      1680
#
#     micro avg       0.79      0.66      0.72      8572
#     macro avg       0.80      0.66      0.72      8572
#  weighted avg       0.79      0.66      0.72      8572
#   samples avg       0.72      0.69      0.69      8572
